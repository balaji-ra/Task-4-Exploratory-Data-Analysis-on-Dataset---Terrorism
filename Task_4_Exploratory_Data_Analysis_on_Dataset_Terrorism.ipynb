# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette('rainbow')

import warnings
warnings.filterwarnings("ignore")

# %%
# Loading the Data
df = pd.read_csv(r"/content/globalterrorismdb_0718dist.csv",encoding='latin1')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
# Showing no. of rows and columns in a dataset
df.shape
# Out:
# (14259, 135)

# %%
# Showing Columns of the Data 
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Showing Data Types of the columns
df.dtypes
# Out:
# eventid         int64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG       float64
# INT_IDEO      float64
# INT_MISC      float64
# INT_ANY       float64
# related        object
# Length: 135, dtype: object

# %%
# Extracting Important Columns
df = df[['iyear','imonth','iday','country_txt','provstate','region_txt',
                       'attacktype1_txt','target1','nkill','nwound','summary','gname', 
                       'targtype1_txt','weaptype1_txt','motive']]

# %%
# Renaming of Columns
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#                        AttackType                   Target  Killed  Wounded  \
# 0                   Assassination             Julio Guzman     1.0      0.0
# 1     Hostage Taking (Kidnapping)  Nadine Chaval, daughter     0.0      0.0
# 2                   Assassination                 Employee     1.0      0.0
# 3               Bombing/Explosion             U.S. Embassy     NaN      NaN
# 4  Facility/Infrastructure Attack           U.S. Consulate     NaN      NaN
#
#   Summary                               Group                  Target_type  \
# 0     NaN                              MANO-D  Private Citizens & Property
# 1     NaN  23rd of September Communist League      Government (Diplomatic)
# 2     NaN                             Unknown          Journalists & Media
# 3     NaN                             Unknown      Government (Diplomatic)
# 4     NaN                             Unknown      Government (Diplomatic)
#
#   Weapon_type Motive
# 0     Unknown    NaN
# 1     Unknown    NaN
# 2     Unknown    NaN
# 3  Explosives    NaN
# 4  Incendiary    NaN

# %%
# Checking for duplicated values
df.duplicated().sum()
# Out:
# 883

# %%
# Dropping Duplicated Values
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (13376, 15)

# %%
## Checking for duplicated values
df.duplicated().any()
# Out:
# False

# %%
# Checking No. of unique values in the columns
df.nunique()
# Out:
# Year              13
# Month             13
# Day               32
# Country          121
# State            700
# Region            12
# AttackType         9
# Target         10439
# Killed            61
# Wounded           75
# Summary          878
# Group            856
# Target_type       22
# Weapon_type       11
# Motive           290
# dtype: int64

# %%
# Checking for null values
df.isna().sum().sort_values()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# Region             0
# AttackType         1
# Group              1
# Target_type        1
# Weapon_type        1
# State             64
# Target           128
# Killed          1855
# Wounded         3236
# Summary        12497
# Motive         12733
# dtype: int64

# %%
# Counting Values of State Column 
df['State'].value_counts()
# Out:
# Northern Ireland    1596
# San Salvador         733
# Lazio                412
# California           412
# Unknown              412
#                     ...
# Yvelines               1
# Midland                1
# Limerick               1
# Doha                   1
# Tacna                  1
# Name: State, Length: 700, dtype: int64

# %%
# Treating Null Values in State Column
df['State'] = df['State'].replace({'Unknown': np.nan})
df['State'] = df['State'].fillna("Others")
df['State'].value_counts()
# Out:
# Northern Ireland    1596
# San Salvador         733
# Others               476
# California           412
# Lazio                412
#                     ...
# Yvelines               1
# Midland                1
# Limerick               1
# Doha                   1
# Tacna                  1
# Name: State, Length: 700, dtype: int64

# %%
# Checking for null values
df['State'].isna().any()
# Out:
# False

# %%
# Counting values for Target Column
df['Target'].value_counts()
# Out:
# Military Unit                      123
# Bank                                86
# unit                                62
# Police Station                      50
# bank                                46
#                                   ...
# Cornelius McCrory, 17, Catholic      1
# Carol McMenamy, 15, Catholic         1
# Conquistador Sheraton Hotel          1
# El Al Airlines office                1
# Revolutionary Committee Office       1
# Name: Target, Length: 10439, dtype: int64

# %%
# Treating Null Values in Target Column
df['Target'] = df['Target'].replace({'Unknown': np.nan})
df['Target'] = df['Target'].fillna("Others")
df['Target'].value_counts()
# Out:
# Others                             133
# Military Unit                      123
# Bank                                86
# unit                                62
# Police Station                      50
#                                   ...
# Cornelius McCrory, 17, Catholic      1
# Carol McMenamy, 15, Catholic         1
# Conquistador Sheraton Hotel          1
# El Al Airlines office                1
# Revolutionary Committee Office       1
# Name: Target, Length: 10439, dtype: int64

# %%
# Checking for null values
df['Target'].isnull().any()
# Out:
# False

# %%
# Counting Values for Killed Column and Wounded Column
print(df['Killed'].value_counts())
print(df['Wounded'].value_counts())
# Out:
# 0.0     6832
# 1.0     3072
# 2.0      634
# 3.0      279
# 4.0      161
#         ...
# 73.0       1
# 92.0       1
# 88.0       1
# 31.0       1
# 74.0       1
# Name: Killed, Length: 61, dtype: int64
# 0.0      8130
# 1.0       854
# 2.0       338
# 3.0       173
# 4.0       106
#          ...
# 43.0        1
# 44.0        1
# 52.0        1
# 46.0        1
# 161.0       1
# Name: Wounded, Length: 75, dtype: int64

# %%
# Checking for Outliers in Killed and Wouded Column
df[['Killed','Wounded']].plot(kind='box')
# Out:
# <Axes: >

# %%
# Treating Null Values in Killed and Wounded Column with median
df[['Killed', 'Wounded']] = df[['Killed', 'Wounded']].fillna(df[['Killed', 'Wounded']].mean())
df[['Killed','Wounded']].isnull().any()
# Out:
# Killed     False
# Wounded    False
# dtype: bool

# %%
# Dropping Null Values of Summary and Motive Column
df = df.dropna(subset=['Summary'])
df = df.dropna(subset=['Motive'])

# %%
# Checking for null values
df[['Summary','Motive']].isna().any()
# Out:
# Summary    False
# Motive     False
# dtype: bool

# %%
# checking Unique Values of Day Column
df['Day'].unique()
# Out:
# array([ 1,  2,  3,  6,  9, 12, 13, 19, 22, 25, 26, 27, 30,  4,  8, 15, 16,
#        17, 21, 23, 24,  5, 10, 11, 14, 20, 31,  0, 29,  7, 18, 28])

# %%
# Changing Data of Day Column
df['Day'] = df['Day'].replace(0,np.nan)
df = df.dropna(subset=['Day'])

# Checking no. of unique values in Day Column
print(df['Day'].nunique())

# Checking for null values
print(df['Day'].isnull().any())
# Out:
# 31
# False

# %%
# Checking for Null Values
df.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# State          0
# Region         0
# AttackType     0
# Target         0
# Killed         0
# Wounded        0
# Summary        0
# Group          0
# Target_type    0
# Weapon_type    0
# Motive         0
# dtype: int64

# %%
df.head()
# Out:
#     Year  Month  Day        Country        State         Region  \
# 5   1970      1  1.0  United States     Illinois  North America
# 8   1970      1  2.0  United States    Wisconsin  North America
# 9   1970      1  3.0  United States    Wisconsin  North America
# 11  1970      1  6.0  United States     Colorado  North America
# 14  1970      1  9.0  United States  Puerto Rico  North America
#
#                         AttackType  \
# 5                    Armed Assault
# 8   Facility/Infrastructure Attack
# 9   Facility/Infrastructure Attack
# 11  Facility/Infrastructure Attack
# 14  Facility/Infrastructure Attack
#
#                                                Target  Killed  Wounded  \
# 5                           Cairo Police Headquarters     0.0      0.0
# 8   R.O.T.C. offices at University of Wisconsin, M...     0.0      0.0
# 9   Selective Service Headquarters in Madison Wisc...     0.0      0.0
# 11           Army Recruiting Station, Denver Colorado     0.0      0.0
# 14                                      Baker's Store     0.0      0.0
#
#                                               Summary  \
# 5   1/1/1970: Unknown African American assailants ...
# 8   1/2/1970: Karl Armstrong, a member of the New ...
# 9   1/3/1970: Karl Armstrong, a member of the New ...
# 11  1/6/1970: Unknown perpetrators threw a Molotov...
# 14  1/9/1970:  The Armed Commandos of Liberation c...
#
#                             Group           Target_type Weapon_type  \
# 5              Black Nationalists                Police    Firearms
# 8                 New Year's Gang              Military  Incendiary
# 9                 New Year's Gang  Government (General)  Incendiary
# 11            Left-Wing Militants              Military  Incendiary
# 14  Armed Commandos of Liberation              Business  Incendiary
#
#                                                Motive
# 5      To protest the Cairo Illinois Police Deparment
# 8         To protest the War in Vietnam and the draft
# 9         To protest the War in Vietnam and the draft
# 11                  Protest the draft and Vietnam War
# 14  To protest United States owned businesses in P...

# %%
# Resetting index
df.reset_index(inplace=True,drop=True)
df.head()
# Out:
#    Year  Month  Day        Country        State         Region  \
# 0  1970      1  1.0  United States     Illinois  North America
# 1  1970      1  2.0  United States    Wisconsin  North America
# 2  1970      1  3.0  United States    Wisconsin  North America
# 3  1970      1  6.0  United States     Colorado  North America
# 4  1970      1  9.0  United States  Puerto Rico  North America
#
#                        AttackType  \
# 0                   Armed Assault
# 1  Facility/Infrastructure Attack
# 2  Facility/Infrastructure Attack
# 3  Facility/Infrastructure Attack
# 4  Facility/Infrastructure Attack
#
#                                               Target  Killed  Wounded  \
# 0                          Cairo Police Headquarters     0.0      0.0
# 1  R.O.T.C. offices at University of Wisconsin, M...     0.0      0.0
# 2  Selective Service Headquarters in Madison Wisc...     0.0      0.0
# 3           Army Recruiting Station, Denver Colorado     0.0      0.0
# 4                                      Baker's Store     0.0      0.0
#
#                                              Summary  \
# 0  1/1/1970: Unknown African American assailants ...
# 1  1/2/1970: Karl Armstrong, a member of the New ...
# 2  1/3/1970: Karl Armstrong, a member of the New ...
# 3  1/6/1970: Unknown perpetrators threw a Molotov...
# 4  1/9/1970:  The Armed Commandos of Liberation c...
#
#                            Group           Target_type Weapon_type  \
# 0             Black Nationalists                Police    Firearms
# 1                New Year's Gang              Military  Incendiary
# 2                New Year's Gang  Government (General)  Incendiary
# 3            Left-Wing Militants              Military  Incendiary
# 4  Armed Commandos of Liberation              Business  Incendiary
#
#                                               Motive
# 0     To protest the Cairo Illinois Police Deparment
# 1        To protest the War in Vietnam and the draft
# 2        To protest the War in Vietnam and the draft
# 3                  Protest the draft and Vietnam War
# 4  To protest United States owned businesses in P...

# %%
# Showing Information about the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         636 non-null    int64
#  1   Month        636 non-null    int64
#  2   Day          636 non-null    float64
#  3   Country      636 non-null    object
#  4   State        636 non-null    object
#  5   Region       636 non-null    object
#  6   AttackType   636 non-null    object
#  7   Target       636 non-null    object
#  8   Killed       636 non-null    float64
#  9   Wounded      636 non-null    float64
#  10  Summary      636 non-null    object
#  11  Group        636 non-null    object
#  12  Target_type  636 non-null    object
#  13  Weapon_type  636 non-null    object
#  14  Motive       636 non-null    object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 74.7+ KB

# %%
# Showing Statistical Summary of Numerical Columns
df.describe()
# Out:
#               Year       Month         Day      Killed     Wounded
# count   636.000000  636.000000  636.000000  636.000000  636.000000
# mean   1972.952830    5.680818   15.018868    0.295973    0.447408
# std       3.407399    3.354209    8.669957    1.316094    2.173065
# min    1970.000000    1.000000    1.000000    0.000000    0.000000
# 25%    1970.000000    3.000000    7.000000    0.000000    0.000000
# 50%    1971.000000    5.000000   15.000000    0.000000    0.000000
# 75%    1975.000000    8.000000   22.000000    0.000000    0.000000
# max    1986.000000   12.000000   31.000000   22.000000   36.000000

# %%
# showing Summary of Categorical Columns
df.describe(include='O')
# Out:
#               Country       State         Region         AttackType  \
# count             636         636            636                636
# unique             11          53              6                  8
# top     United States  California  North America  Bombing/Explosion
# freq              624         141            624                287
#
#                   Target                                            Summary  \
# count                636                                                636
# unique               569                                                635
# top     department store  8/18/1972: In a series of five related inciden...
# freq                  14                                                  2
#
#                       Group Target_type Weapon_type   Motive
# count                   636         636         636      636
# unique                   81          19           8      287
# top     Left-Wing Militants    Business  Explosives  Unknown
# freq                    119         153         286       68

# %%
# Filter relevant columns
df_hotzones = df[['Country', 'Region']]

# Count occurrences
country_counts = df_hotzones['Country'].value_counts()
region_counts = df_hotzones['Region'].value_counts()

# Identify hot zones
top_countries = country_counts.head(10)
top_regions = region_counts.head(10)

# Visualize the hot zones
plt.figure(figsize=(12, 6))

# Plot the top countries with the highest number of terrorist incidents
plt.subplot(1, 2, 1)
top_countries.plot(kind='bar')
plt.title('Top 10 Countries with Highest Terrorism Incidents')
plt.xlabel('Country')
plt.ylabel('Number of Incidents')

# Plot the top regions with the highest number of terrorist incidents
plt.subplot(1, 2, 2)
top_regions.plot(kind='bar')
plt.title('Top 10 Regions with Highest Terrorism Incidents')
plt.xlabel('Region')
plt.ylabel('Number of Incidents')

plt.tight_layout()
plt.show()

# %%
df.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# # **Year wise :**

# %%
# Plotting Countplot to show Attacks per Year
plt.figure(figsize=(14,4))
sns.countplot(x = df['Year'])
plt.title('Terrorist Activities per Year')
plt.xlabel('Attacking Years')
plt.ylabel('No. of Attacks per Years')
plt.xticks(rotation=90)
plt.show()

# %%
# Showing Peoples Kiled Per Year
kill_per_year = df[['Year','Killed']].groupby('Year').sum()
kill_per_year.plot(kind='bar', figsize=(15,5), title = 'No. of People Killed Per Year')
plt.xlabel('Attacking Years')
plt.ylabel('No.of Peoples Killed ')
plt.show()

# %%
wounded_per_year = df[['Year','Wounded']].groupby('Year').sum()
wounded_per_year.plot(kind='bar', figsize=(15,5), title = 'No. of People Wounded Per Year')
plt.xlabel('Attacking Years')
plt.ylabel('No.of Peoples Wounded')
plt.show()

# %% [markdown]
# # **Month Wise :**

# %%
df['Month'].value_counts().plot(kind='bar', title = 'Terrorist Activities per Month')
plt.xlabel('Attacking Months')
plt.ylabel('No. of Attacks per Month')
plt.show()

# %%
kill_wounded_per_month = df[['Killed','Wounded','Month']].groupby('Month').sum()
kill_wounded_per_month.plot(kind='bar', title = 'No. Of People Killed and Wounded Each Month')
plt.xlabel('Attacking Months')
plt.ylabel('No. of People Killed and wounded')
plt.show()

# %%
plt.figure(figsize=(15,5))
most_attack_countries = df['Country'].value_counts().head(20)
most_attack_countries.plot(kind='bar')
plt.title('Top 20 Mostly Attacked Countries')
plt.xlabel('Countries')
plt.ylabel('No. of Attacks')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **State Wise :**

# %%
plt.figure(figsize=(15,10))
most_attack_countries = df['State'].value_counts().head(10)
most_attack_countries.plot(kind='pie',autopct = '%.2f%%')
plt.title('Top 10 Mostly Attacked States')
plt.xlabel('States')
plt.ylabel(None)
plt.show()

# %% [markdown]
# # **Region wise :**

# %%
plt.figure(figsize=(10,5))
most_attack_regions = df['Region'].value_counts().head(7)
most_attack_regions.plot(kind='bar')
plt.title('Top 7 Mostly Attacked Regions')
plt.xlabel('Regions')
plt.ylabel('No. of Attacks')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **AttackType Wise :**

# %%
# Plotting Most Used Attacks Types by Terrorist
plt.figure(figsize=(10,5))
most_attack_regions = df['AttackType'].value_counts()
most_attack_regions.plot(kind='bar')
plt.title('Most Used Attack Types By Terrorists')
plt.xlabel('Type of Attacks')
plt.ylabel('No. of Terrorist Attacks')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Target Wise :**

# %%
df['Target'].value_counts()
# Out:
# department store                                                                   14
# Others                                                                             12
# bank                                                                               11
# Cairo Police Headquarters                                                           4
# Interracial couple                                                                  4
#                                                                                    ..
# Campaign Headquarters of Parren Mitchell                                            1
# Toledo Police officer stationed outside of the Black Panther Party Headquarters     1
# R.O.T.C. building, University of Florida                                            1
# Offices of the Kaleidoscope, Madison Wisconsin                                      1
# PREPA electric substation in Laguna Gardens, Puerto Rico                            1
# Name: Target, Length: 569, dtype: int64

# %%
plt.figure(figsize=(10,5))
most_target_peoples = df['Target'].value_counts().head(10)
most_target_peoples.plot(kind='bar')
plt.title('Most Target Peoples by Terrorists Attacks')
plt.xlabel('Most Target Peoples')
plt.ylabel('No. of Terrorists Attacks')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Group Wise :**

# %%
terr_groups = df['Group'].value_counts()
terr_groups
# Out:
# Left-Wing Militants                              119
# Black Nationalists                                53
# White extremists                                  52
# Unknown                                           46
# Fuerzas Armadas de Liberacion Nacional (FALN)     42
#                                                 ...
# Lolita Lebron Puerto Rican Liberation Command      1
# Stop the War Coalition                             1
# African-American extremists                        1
# Ananda Marga                                       1
# Grupo Estrella                                     1
# Name: Group, Length: 81, dtype: int64

# %%
# Plotting Top 10 Groups Most Terrorist Attacks
fig = plt.figure(figsize=(15,5))
sns.barplot(x= terr_groups[1:11].index, y = terr_groups[1:11].values)
plt.title('Groups with Most Terrorist Attacks')
plt.xlabel('Terrorist Groups')
plt.ylabel('Number of Terrorist Attacks')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Target wise :**

# %%
targets = df['Target_type'].value_counts()
targets
# Out:
# Business                          153
# Private Citizens & Property        97
# Military                           91
# Government (General)               89
# Police                             62
# Educational Institution            51
# Religious Figures/Institutions     16
# Journalists & Media                14
# Utilities                          12
# NGO                                10
# Abortion Related                    8
# Government (Diplomatic)             7
# Unknown                             6
# Airports & Aircraft                 6
# Transportation                      4
# Telecommunication                   4
# Food or Water Supply                4
# Violent Political Party             1
# Terrorists/Non-State Militia        1
# Name: Target_type, dtype: int64

# %%
fig = plt.figure(figsize=(15,6))
sns.barplot(x = targets.index, y = targets.values)
plt.title("Most frequent target types of terrorists")
plt.xlabel("Targets")
plt.ylabel("Number of Terrorist Attacks")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Weapon_Type wise :**

# %%
weapon_used = df['Weapon_type'].value_counts().head()
weapon_used
# Out:
# Explosives    286
# Incendiary    198
# Firearms      128
# Melee           7
# Chemical        7
# Name: Weapon_type, dtype: int64

# %%
fig = plt.figure(figsize=(15,5))
sns.barplot(y = weapon_used.index, x = weapon_used.values)
plt.title("Most Weapon Used")
plt.xlabel("Number of Terrorist Attacks")
plt.ylabel("Weapons")
plt.xticks(rotation=90)
plt.show()

# %%
# Showing Correlation Between different Columns
sns.heatmap(df.corr(),annot=True,cmap='viridis')
plt.show()

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'State', 'Region', 'AttackType',
#        'Target', 'Killed', 'Wounded', 'Summary', 'Group', 'Target_type',
#        'Weapon_type', 'Motive'],
#       dtype='object')

# %% [markdown]
# # Gathering Insights From The Data
#
# 1. Year with Most Number of People Wounded - 2001
# 2. Country with Most Attacks - Iraq
# 3. Year with Most Number of People Killed - 2007
# 4. Most frequent Weapon Used - Explosives.
# 5. Month in which Most No. of People Killed - August
# 6. Month in which Most No. of People Wounded - September
# 7. Year with Most Number of Attacks - 2011
# 8. State with Most Attacks - Baghdad
# 9. Region with most Attacks - SouthAsia
# 10. Most frequent Target Types - Private Citizens and Property
# 11. Most Used Attack Types by terrorists - Bombing/Explosion
# 13. Most Targeted People - Civillians
# 14. Group with most nO. of attacks - Taliban
# 15. Month with Most No. of Attacks - November
